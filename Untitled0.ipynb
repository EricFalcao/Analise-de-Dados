# %% [markdown]
# <a href="https://colab.research.google.com/github/EricFalcao/Analise-de-Dados/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandasql
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26771 sha256=191a7583e46ec267a8bd28787bfc2ab7d9ec4bebcc684b2c5576ad2523b32990
#   Stored in directory: /root/.cache/pip/wheels/e9/bc/3a/8434bdcccf5779e72894a9b24fecbdcaf97940607eaf4bcdf9
# Successfully built pandasql
# ...

# %%
import pandas as pd

# %%
import pandasql as ps

# %% [markdown]
# ### Lendo as bases de dados

# %%
dim_cargo = pd.read_csv('https://raw.githubusercontent.com/rgaguiar/banco_lotacao/main/cargo.csv')
dim_departamento = pd.read_csv('https://raw.githubusercontent.com/rgaguiar/banco_lotacao/main/departamento.csv')
dim_funcionario = pd.read_csv('https://raw.githubusercontent.com/rgaguiar/banco_lotacao/main/funcionario.csv')
fato_lotacao = pd.read_csv('https://raw.githubusercontent.com/rgaguiar/banco_lotacao/main/lotacao.csv')

# %%
print('tabela dim_cargo')
display(dim_cargo.head(2))
print('dim_departamento')
display(dim_departamento.head(2))
# Out:
# tabela dim_cargo
#    id               nome
# 0   1  Analista de Dados
# 1   2        Programador
# dim_departamento
#    id                      nome
# 0   1  Tecnologia da Informação
# 1   2            Administrativo

# %% [markdown]
# #Aplicando instruções em SQL

# %% [markdown]
# Quantos registros possui o banco lotação?

# %%
query = """
select
'Numero de Registros'as Nome,
count(*) as quantidade
from fato_lotacao
"""
ps.sqldf(query, locals())
# Out:
#                   Nome  quantidade
# 0  Numero de Registros          13

# %% [markdown]
# O banco possui 13 registros.

# %% [markdown]
# Departamento com a maior folha salarial?

# %%
display(dim_departamento.head(2))
display(fato_lotacao.head(2))
# Out:
#    id                      nome
# 0   1  Tecnologia da Informação
# 1   2            Administrativo
#    id  id_funcionario  id_departamento  id_cargo  salario    cadastro  ativo
# 0   1               1                1         1   9000.0  2022-09-01   True
# 1   2               2                2         2   7500.0  2022-09-02   True

# %%
query = """
select
dp.nome as departamento
sum(lt.salario) as maior_salario_dp
from fato_lotacao as lt
inner join dim_departamento as dp on dp.id=id.id_departamento
group by
dp.nome

"""
ps.sqldf(query, locals())
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in _exec_single_context(self, dialect, context, statement, parameters)
#    1970                 if not evt_handled:
# -> 1971                     self.dialect.do_execute(
#    1972                         cursor, str_statement, effective_parameters, context
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     918     def do_execute(self, cursor, statement, parameters, context=None):
# --> 919         cursor.execute(statement, parameters)
#     920
#
# OperationalError: near "sum": syntax error
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ...

# %% [markdown]
# Cargo melhor remjunerado(em media)?

# %%
query = """
select
dg.nome as cargo
avg(lt.salario) as media_salario
from fato_lotacao as lt
inner join dim_cargo as cg on cg.id=lt.id_cargo
group by
cg.nome
order by media_salario desc
"""
ps.sqldf(query, locals())
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in _exec_single_context(self, dialect, context, statement, parameters)
#    1970                 if not evt_handled:
# -> 1971                     self.dialect.do_execute(
#    1972                         cursor, str_statement, effective_parameters, context
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     918     def do_execute(self, cursor, statement, parameters, context=None):
# --> 919         cursor.execute(statement, parameters)
#     920
#
# OperationalError: near "avg": syntax error
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ...
